# %%
import pandas as pd
import random

w = []
y = []
for i in range(1,10000):
    v = random.random()
    w.append(v)
    if ( random.random() > v ):
        y.append(v)
    
    
s = pd.Series(y)
s.hist()
# Out:
# <Axes: >
